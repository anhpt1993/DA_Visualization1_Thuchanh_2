# %% [markdown]
# # 0. Khai báo các thư viện cần thiết

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Đọc file dữ liệu CSV

# %%
df = pd.read_csv("https://s3.ap-southeast-1.amazonaws.com/learn.codegym.vn/media/public/2022/02/16091503/daily-min-temperatures.csv", encoding = "ISO-8859-1")
df.head()
# Out:
#          Date  Temp
# 0  1981-01-01  20.7
# 1  1981-01-02  17.9
# 2  1981-01-03  18.8
# 3  1981-01-04  14.6
# 4  1981-01-05  15.8

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3650 entries, 0 to 3649
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3650 non-null   object
#  1   Temp    3650 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 57.2+ KB

# %%
df.describe()
# Out:
#               Temp
# count  3650.000000
# mean     11.177753
# std       4.071837
# min       0.000000
# 25%       8.300000
# 50%      11.000000
# 75%      14.000000
# max      26.300000

# %% [markdown]
# # 2. Chọn mục tiêu Vẽ biểu đồ Histogram phân tích các giá trị thống kê như max, min, mode, tần suất. Vẽ biểu đồ đường phân tích xu hướng thay đổi nhiệt độ theo thời gian.

# %% [markdown]
# - 2.1. Vẽ biểu đồ histogram

# %%
plt.hist(df.Temp, bins = 45)
plt.show()

# %%
# Tinh chỉnh biểu đồ
plt.hist(df.Temp, bins = 45, range = (1, 23), histtype = "step")
plt.title("Temperature Histogram", fontsize = 16)
plt.xlabel("Date", fontsize = 14)
plt.ylabel("Temperature", fontsize = 14)
plt.show()

# %% [markdown]
#     Nhận xét:
#
#         - Giá trị xuất hiện nhiều nhất là trong khoảng 10-11 độ.
#         - Có một số giá trị bất thường ở cả 2 phía. Một số rất ít ngày có nhiệt độ cao bất thường trên 23 độ và thấp bất thường dưới 1 độ.
#         - Nhìn chung, nếu loại bỏ các ngày có giá trị bất thường, có thể nói nhiệt độ tuân theo phân phối chuẩn.

# %% [markdown]
# - 2.2. Vẽ biểu đồ đường thể hiện xu hướng nhiệt độ

# %%
plt.plot(df.Date, df.Temp)
plt.title("Dayly Temperature", fontsize = 16)
plt.xlabel("Date", fontsize = 14)
plt.ylabel("Temp", fontsize = 14)
plt.show()

# %% [markdown]
#     Nhận xét:
#
#         - Có thể thay xu hướng thay đổi nhiệt độ có tính chu kỳ.
#         - Dựa vào đồ thị, ta phán đoán chu kì thay đổi của nhiệt độ là theo năm.
#         - Tuy nhiên, do khoảng thời gian biểu diễn dài nên khó có thể nhìn chi tiết xu hướng biến đổi nhiệt độ trong năm. Do đó ta vẽ bổ sung biểu đồ đường thể hiện xu hướng nhiệt độ theo từng năm quan tâm.

# %% [markdown]
# - 2.3. Vẽ biểu đồ đường xu hướng nhiệt độ của năm 1990

# %%
df.Date = pd.to_datetime(df.Date)
bounds = ["1/1/1990", "12/31/1990"]
bounds = pd.to_datetime(bounds)

# %%
conditions = (df.Date >= bounds[0]) & (df.Date <= bounds[1])
new_df = df[conditions]

# %%
# Vẽ biểu đồ đường
plt.plot(new_df.Date, new_df.Temp)
plt.title("Dayly Temperature in 1990", fontsize = 16)
plt.xlabel("Date", fontsize = 14)
plt.ylabel("Temp", fontsize = 14)
plt.show()

# %% [markdown]
#     Nhận xét:
#
#         - Nhiệt độ có xu hướng giảm từ tháng 5 và bắt đầu tăng trở lại vào tháng 9.
#         - 3 tháng đầu năm có nhiệt độ trung bình cao nhất.
